# %%
lst=[1,2,3,4,5,5,5]
lst1=['a','b','c']
lst2=[8,9,10]
# access the element in a list 
lst[0:3]
lst[2]

#find the occurance of the object in a list
lst.count(5)

#append an object into a list
lst.append(lst2)

#append an iterble into a list
lst.extend(lst2)

#concatenate two list into a new list
newlist=lst1 + lst2

#remove first occurance of a value
#try:
#    lst.remove(12)
#except:
#    print("value error: object is not in the list")

#insert an object before an index position
lst3=[1,2,3,4,5,5,5]
lst3.insert(3,9)

#remeove an object based on the index
lst3.pop(3)

#reverse an list
lst3.reverse()

#sort a list
lst3.sort()

#print(lst3)

#extract every last two elements from a list
NAME=['ARUNRAJ','BINURAJ','DINESHRAJ']
lname=[nm[-3:] for nm in NAME ]
fname=[nm[:-3] for nm in NAME ]
nametuple=tuple(zip(fname,lname))
#print(nametuple)

#adding a constant in each element in a list
number=[2,3,4,5,6,9]
numburplus=[num+2 for num in number]

#adding a tuple to list and vice-versa
name=['ARUNRAJ','BINURAJ','DINESHRAJ']
nametup=('DEEPARAJ')
name.append(nametup)
name1=tuple(name)
#print(name1)

#find the index postion of an element in the list and remove
text=['abendr+edhr','fjjgr+er','fhhrhedg+']
cleantext=[txt.replace('+','') for txt in text ]


lst1=['a','b','c']
lst2=[8,9,10]
# access the element in a list 
lst[0:3]
lst[2]

#find the occurance of the object in a list
lst.count(5)

#append an object into a list
lst.append(lst2)

#append an iterble into a list
lst.extend(lst2)

#concatenate two list into a new list
newlist=lst1 + lst2

#remove first occurance of a value
#try:
#    lst.remove(12)
#except:
#    print("value error: object is not in the list")

#insert an object before an index position
lst3=[1,2,3,4,5,5,5]
lst3.insert(3,9)

#remeove an object based on the index
lst3.pop(3)

#reverse an list
lst3.reverse()

#sort a list
lst3.sort()

#print(lst3)

#extract every last two elements from a list
NAME=['ARUNRAJ','BINURAJ','DINESHRAJ']
lname=[nm[-3:] for nm in NAME ]
fname=[nm[:-3] for nm in NAME ]
nametuple=tuple(zip(fname,lname))
#print(nametuple)

#adding a constant in each element in a list
number=[2,3,4,5,6,9]
numburplus=[num+2 for num in number]

#adding a tuple to list and vice-versa
name=['ARUNRAJ','BINURAJ','DINESHRAJ']
nametup=('DEEPARAJ')
name.append(nametup)
name1=tuple(name)
#print(name1)

#find the index postion of an element in the list and remove
text=['abendr+edhr','fjjgr+er','fhhrhedg+']
cleantext=[txt.replace('+','') for txt in text ]

lst1=['a','b','c']
lst2=[8,9,10]
# access the element in a list 
lst[0:3]
lst[2]

#find the occurance of the object in a list
lst.count(5)

#append an object into a list
lst.append(lst2)

#append an iterble into a list
lst.extend(lst2)

#concatenate two list into a new list
newlist=lst1 + lst2

#remove first occurance of a value
#try:
#    lst.remove(12)
#except:
#    print("value error: object is not in the list")

#insert an object before an index position
lst3=[1,2,3,4,5,5,5]
lst3.insert(3,9)

#remeove an object based on the index
lst3.pop(3)

#reverse an list
lst3.reverse()

#sort a list
lst3.sort()

#print(lst3)

#extract every last two elements from a list
NAME=['ARUNRAJ','BINURAJ','DINESHRAJ']
lname=[nm[-3:] for nm in NAME ]
fname=[nm[:-3] for nm in NAME ]
nametuple=tuple(zip(fname,lname))
#print(nametuple)

#adding a constant in each element in a list
number=[2,3,4,5,6,9]
numburplus=[num+2 for num in number]

#adding a tuple to list and vice-versa
name=['ARUNRAJ','BINURAJ','DINESHRAJ']
nametup=('DEEPARAJ')
name.append(nametup)
name1=tuple(name)
#print(name1)

#find the index postion of an element in the list and remove
text=['abendr+edhr','fjjgr+er','fhhrhedg+']
#cleantext=[txt.replace('+','') for txt in text ]

#remove bad characters from a list
text=['abdef@dhdf#','abferdd*!','higklw~ert&']
bad_txt=['~','!','@','#','$','%','^','&','*']
var='!@#$%^&*~'
removable=str.maketrans('','',var)
cleantext =[x.translate(removable) for x in text]
#print(cleantext)

#remove element from a lsit based on index
newtext=[]
mylist=['abdef','cder','fghi']
def rmvelm(lst,pos):
        lst.pop(pos) 
a=rmvelm(mylist,2)        
#print(mylist)        

#remove duplicate dictionary in a list
test_list = [{"Akshat" : 3}, {"Akash" : 1}, {"Kil" : 2}, {"Akshat" : 3}, {"Kil" : 2}, {"Akshat" : 3}, {"Akshat" : 3}] 
test_list1=[]
for i in range(len(test_list)):
    if test_list[i] not in test_list1:
        test_list1.append(test_list[i])
#use list comprehension to solve above problem
test_list1=[i for n , i in enumerate(test_list) if i not in test_list[n+1:]]
print(test_list1)
# Out:
# [{'Akash': 1}, {'Kil': 2}, {'Akshat': 3}]

# %%
# extract unique element from a list

lst1=[1,2,3,4,5,5,5,6,6,6]
un_lst=[]
def unique_lst(lst):
    lst_set=set(lst)
    un_lst=(list(lst_set))
    return un_lst

a=unique_lst(lst1)

#count if any of the element in the list occured more than once
mr_list=[]
def more_than_one_occ(occ):
    for i in a:
        if lst1.count(i)>occ:
            mr_list.append(i)
    return mr_list
b=more_than_one_occ(2)

#convert a list into string 
stlist=['I','love','my','country']

#use function to convert
def listTostr():
    newstr=" "
    return (newstr.join(stlist))
b=listTostr()

#use list comprehension  to convert
str_lstcomp=' '.join([str(elmt) for elmt in stlist])

#use map funtion to convert
str_map=' '.join(map(str,stlist))

#convert a string to list
lst_str=str_map.split(" ")
print(type(lst_str))
# Out:
# <class 'list'>

# %%
#list comprehension example
lst=[1,2,3,4,5,6]
lst_square=[elmt**2 for elmt in lst]

#check a number divisible by even number
lst_even=[elmt for elmt in lst if elmt % 2==0]
print(lst_even)
# Out:
# [2, 4, 6]

# %%
uniq_list=[]
lst1=[1,2,3,4,5,5,5]
for i in lst1:
    if i not in uniq_list:
        uniq_list.append(i)
print(uniq_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(lst)
# Out:
# [1, 2, 3, 4, 5]

# %%
#work on tuples
#create a tuples
tup=(2,3,4)
a=2,3,4,'arun'

#create a tuple with one element
a=(1,)
#print(type(a))

#accessing python tuples
a=(2,4,6,8,9,12,14)
a[1]
a[1:3]
a[2:]
a[1:-1]

#tuples are immutable. If its hold a mutable item such as list or dict then we can update  tupple e.g:

tup=(2,3,4,5,[7,8])
tup[4][0]=8
#print(tup)

#apply functions in tuples. functions will change construct but will return a result from construct

d=(74,56,4,35,45,56,67)
len(d)
max(d)
min(d)
sum(d)
sorted(d)

#converst another construct into a tuple
lst=[2,4,7]
set1={3,5,6,7}
tpl=tuple(lst)
tpl1=tuple(set1)
#print(tpl1)

#Python Tuple Methods
tup=(3,5,7,3,4,9,11,5)
tup.index(5)
tup.count(4)

#check whether a element belongs to or not
tup2=('a','b','c','d','e')
def test(elm):
    if elm in tup2:
        print ('element is present')
    else:
        print ('element is not present')
a=test('h')

#concatenate two tuples
a=(2,3,4)
b=(5,6,7)
c=a+b
#print(c)

#zip function example
for i in zip([1,2,3],['a','b','c']):
    print(i)
for i in zip([1,2,3,4,5,6],['a','b','c','d']):
    print(i)
a=list(zip([1,2,3,4,5,6],['a','b','c','d']))
#print(a)
# Out:
# element is not present
# (1, 'a')
# (2, 'b')
# (3, 'c')
# (1, 'a')
# (2, 'b')
# (3, 'c')
# (4, 'd')

# %%
#Examples of dictionary
dict1={'L7280848':'ARUN','G3380350N':'Binu'}
#create an empty dictionary
dict2={}
type(dict2)

#create dictionary comprehension
dict3={x:x*x for x in range(2,8)}
#print(dict3)

#create dictionary with mixed keys
dict4={1:'arun','two':2}
#print(dict4)

#convert list or tuple into dictionary if its compatible
lst=[1,2],[2,3],[3,4]
dict5=dict(lst)
#print(dict5)

#declare an empty dictionary and add elements
dict6={}
dict6[1]='crow'
dict6[2]='kingfisher'
#print(dict6)

#Accessing keys and values in dictionary
#dict3[6]

#updating or adding a key value in dictionary
dict6={1:1,2:2,3:3}
dict6[2]=4
dict6[4]=8
print(dict6)

#delete an python dictionary
del dict4

#delete single key value pair
del dict6[4]
#print(dict6)

#extract keys and vallues separately from dict
key_lst=list(dict6.keys())
value_lst=list(dict6.values())
item_lst=list(dict6.items())

#truncate a dictionary
dict2.clear()

#copy a dictionary but point to same memory  location
dict7=dict3.copy()
del dict3

#remove a key value pair from dictionary
dict7.pop(2)
#print(dict7)

#update a dictionary from another dictionary
dict10={1:1,2:2,3:3}
dict11={5:1,2:5,3:7}
dict10.update(dict11)
#print(dict10)

for i in dict10:
    dict10[i]=dict10[i]*2

print(dict10)
# Out:
# {1: 1, 2: 4, 3: 3, 4: 8}
# {1: 2, 2: 10, 3: 14, 5: 2}

# %%
#examples of collection modules

# %%
import os as os

# %%
#os.getcwd()

#os.chdir('C:\\Users\\P0500387\\Documents\\Python Programmes')

#dirname=os.listdir('C:\\Users\\P0500387\\Documents')


#os.mkdir('C:\\Users\\P0500387\\Documents\\test')

#os.rename('C:\\Users\\P0500387\\Documents\\test','C:\\Users\\P0500387\\Documents\\test1')

#os.remove('C:\\Users\\P0500387\\Documents\\test1\\CASE_20200916.txt')

#os.rmdir('C:\\Users\\P0500387\\Documents\\test1')

#os.path.join('C:','Users','lifei','Desktop')

os.path.exists('C:\\Users\\P0500387\\Documents\\CASE_20200916.txt')

#os.path.isdir('C:\\Users\\P0500387\\Documents')

#for root,dirs,files in os.walk('C:\\Users\\P0500387\\Documents'):
#    print(root,len(dirs),len(files))

#for root,dirs,files in os.walk('C:\\Users\\P0500387\\Documents'):
#    print(root,dirs,files)
    
#for root,dirs in os.walk('C:\\Users\\P0500387\\Documents'):
#    print(root,dirs)

#print(dirname)
# Out:
# True

# %%
# extract all the files from a folder 
import os 
import glob
import pandas as pd
def list_file(ext):
    directory="D:\Source Data\BBO"
    filelist= glob.glob('D:\\Source Data\\BBO\\*.txt')
print(filelist)
# Out:
# []

# %%
# extract filename and location of a source folder and loaded into DF

filelist=[]
def list_file(directory,extention):
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(extention):
                filelist.append(directory + file)
                #return filelist
            else:
                print ("There is no .txt file in the folder")
                
#create a DF from list of files
    if filelist:
        list_files=pd.DataFrame(filelist,columns=['file_name'])
        list_files.head()
        #return list_files
    else:
        print("There is no files to load in the folder")
list_file('D:\\Source Data\\BBO\\','.txt')

# %%
test1=[sub.split('\\') for sub in filelist ]
#test2=test1[:][:-1]
#print(test1)
loc=[]
fname=[]
for i in range(len(test1)):
    a='\\'.join(test1[i][:-1])
    b=test1[i][-1]
    loc.append(a)
    fname.append(b)
flist=dict(zip(fname,loc))
print(flist)
# Out:
# {'BB_CHILD_20191013_081615.txt': 'D:\\Source Data\\BBO', 'BB_PARENT_20191012_081615.txt': 'D:\\Source Data\\BBO'}

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...
